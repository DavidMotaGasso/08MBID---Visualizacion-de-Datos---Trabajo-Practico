# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidMotaGasso/08MBID---Visualizacion-de-Datos---Trabajo-Practico/blob/master/Visualizacion_de_datos_Trabajo_practico_Correlacion_de_puntos%2C_rebotes_y_asistencias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# carga de datos
import pandas as pd
import io
from google.colab import files

# manipulación y visualización
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
import itertools
import seaborn as sns
from numpy import corrcoef, transpose, arange
from pylab import pcolor, show, colorbar, xticks, yticks

# %%
def upload_files ():
  uploaded = files.upload()
  for fn in uploaded.keys():
    print('User uploaded file "{name}" with length {length} bytes'.format(
        name=fn, length=len(uploaded[fn])))
    df = pd.read_csv(io.StringIO(uploaded[fn].decode('utf-8')))
    return df

# %%
dataset = upload_files()
dataset.head()
# Out:
#      <input type="file" id="files-610e2795-3622-4241-97d9-2ad96ddf01aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-610e2795-3622-4241-97d9-2ad96ddf01aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving base_datos_ncaa_visualizacion.csv to base_datos_ncaa_visualizacion.csv
# User uploaded file "base_datos_ncaa_visualizacion.csv" with length 3865176 bytes
#    season                 gametime team_name  \
# 0    2014  2014-11-14 16:00:00 UTC       EWU
# 1    2014  2014-11-14 16:00:00 UTC      TXSO
# 2    2014  2014-11-14 18:00:00 UTC      SHSU
# 3    2014  2014-11-14 18:00:00 UTC       AUS
# 4    2014  2014-11-14 18:30:00 UTC       EMU
#
#                             team_conf_name game_outcome  points_game  \
# 0                                  Big Sky          Win          148
# 1                    Southwestern Athletic         Loss          148
# 2                                Southland          Win          152
# 3  Southern Collegiate Athletic Conference         Loss          152
# 4                             Mid-American          Win          116
#
#    team_points_game  team_three_point_pct  team_two_points_pct  \
# 0                86                  44.1                0.567
# 1                62                  16.0                0.400
# 2               100                  25.0                0.725
# 3                52                   0.0                0.000
# 4                64                  16.7                0.553
#
#    team_free_throws_pct  team_rebounds  team_assists  team_turnovers  \
# 0                  46.7             42            15              15
# 1                  71.0             36             7              14
# 2                  60.0             53            26              15
# 3                   0.0              0             0               0
# 4                  56.5             36             9              10
#
#    team_steals  team_blocks  will_be_in_march_madness
# 0            7            9                         1
# 1            8            1                         1
# 2           11           10                         1
# 3            0            0                         0
# 4           12            4                         1

# %%
# Copia de las bases de datos subidas por poder resetear sin subirlas de nuevo
dataset_visualizacion = dataset.copy()

# %%
dataset_visualizacion
# Out:
#        season                 gametime team_name  \
# 0        2014  2014-11-14 16:00:00 UTC       EWU
# 1        2014  2014-11-14 16:00:00 UTC      TXSO
# 2        2014  2014-11-14 18:00:00 UTC      SHSU
# 3        2014  2014-11-14 18:00:00 UTC       AUS
# 4        2014  2014-11-14 18:30:00 UTC       EMU
# ...       ...                      ...       ...
# 44203    2017  2018-03-04 20:00:00 UTC       TEM
# 44204    2017  2018-03-04 21:00:00 UTC       HOU
# 44205    2017  2018-03-04 21:00:00 UTC      CONN
# 44206    2017  2018-03-04 21:30:00 UTC       UCF
# 44207    2017  2018-03-04 21:30:00 UTC      TULN
#
#                                 team_conf_name game_outcome  points_game  \
# 0                                      Big Sky          Win          148
# 1                        Southwestern Athletic         Loss          148
# 2                                    Southland          Win          152
# 3      Southern Collegiate Athletic Conference         Loss          152
# 4                                 Mid-American          Win          116
# ...                                        ...          ...          ...
# 44203                        American Athletic         Loss          134
# 44204                        American Athletic          Win          152
# 44205                        American Athletic         Loss          152
# 44206                        American Athletic          Win          111
# 44207                        American Athletic         Loss          111
#
#        team_points_game  team_three_point_pct  team_two_points_pct  \
# 0                    86                  44.1                0.567
# 1                    62                  16.0                0.400
# 2                   100                  25.0                0.725
# 3                    52                   0.0                0.000
# 4                    64                  16.7                0.553
# ...                 ...                   ...                  ...
# 44203                58                  24.0               41.700
# 44204                81                  40.0               48.500
# 44205                71                  35.0               63.000
# 44206                60                  31.3               43.800
# 44207                51                  28.6               37.500
#
#        team_free_throws_pct  team_rebounds  team_assists  team_turnovers  \
# 0                      46.7             42            15              15
# 1                      71.0             36             7              14
# 2                      60.0             53            26              15
# 3                       0.0              0             0               0
# 4                      56.5             36             9              10
# ...                     ...            ...           ...             ...
# 44203                  66.7             27             8              12
# 44204                  73.5             32             9              13
# 44205                  66.7             21            10              13
# 44206                  70.8             31             8              11
# 44207                  56.3             37            10              15
#
#        team_steals  team_blocks  will_be_in_march_madness
# 0                7            9                         1
# 1                8            1                         1
# 2               11           10                         1
# 3                0            0                         0
# 4               12            4                         1
# ...            ...          ...                       ...
# 44203           10            3                         1
# 44204            5            0                         1
# 44205            8            1                         0
# 44206            8            4                         0
# 44207            7            2                         0
#
# [44208 rows x 16 columns]

# %%
dataset_variables_visualizacion = dataset_visualizacion[['team_points_game','team_rebounds','team_assists']]
dataset_variables_visualizacion
# Out:
#        team_points_game  team_rebounds  team_assists
# 0                    86             42            15
# 1                    62             36             7
# 2                   100             53            26
# 3                    52              0             0
# 4                    64             36             9
# ...                 ...            ...           ...
# 44203                58             27             8
# 44204                81             32             9
# 44205                71             21            10
# 44206                60             31             8
# 44207                51             37            10
#
# [44208 rows x 3 columns]

# %%
fig=figure(figsize=(20, 20), dpi=80)
sns.set_theme(style="ticks")
sns.pairplot(dataset_variables_visualizacion, height=4) #, hue="species")
